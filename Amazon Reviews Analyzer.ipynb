# %%
import pandas as pd
from collections import Counter

# %%
file = "Toys_and_Games.jsonl"

# %%
asin_counts = Counter()
parent_counts = Counter()

for chunk in pd.read_json(file, lines=True, chunksize=50000):
    asin_counts.update(chunk['asin'].dropna())
    parent_counts.update(chunk['parent_asin'].dropna())

# now after full pass:
# print(asin_counts.most_common(250))

# %%
most_common = asin_counts.most_common(250)

# %%
for i in range(250):
    asin, _ = most_common[i]
    print(f"{i}: https://www.amazon.com/dp/{asin}")
# Out:
# 0: https://www.amazon.com/dp/B004S8F7QM
# 1: https://www.amazon.com/dp/B000YDDF6O
# 2: https://www.amazon.com/dp/B010TQY7A8
# 3: https://www.amazon.com/dp/B00005C5H4
# 4: https://www.amazon.com/dp/B004V3PS72
# 5: https://www.amazon.com/dp/B01MRG7T0D
# 6: https://www.amazon.com/dp/B01AC7SF7K
# 7: https://www.amazon.com/dp/B00ABA0ZOA
# 8: https://www.amazon.com/dp/B000B6ACGA
# 9: https://www.amazon.com/dp/B0157IHJMQ
# 10: https://www.amazon.com/dp/B0120XRWLE
# 11: https://www.amazon.com/dp/B00AU56C5W
# 12: https://www.amazon.com/dp/B001CJVTLC
# 13: https://www.amazon.com/dp/B00000IV35
# 14: https://www.amazon.com/dp/B00A80X19E
# 15: https://www.amazon.com/dp/0975277324
# 16: https://www.amazon.com/dp/B00000IVAK
# 17: https://www.amazon.com/dp/B003I64OT6
# 18: https://www.amazon.com/dp/B00D8STBHY
# 19: https://www.amazon.com/dp/B00APVXSM6
# 20: https://www.amazon.com/dp/B00MNG37C2
# 21: https://www.amazon.com/dp/8499000606
# 22: https://www.amazon.com/dp/B00NQQTZCO
# 23: https://www.amazon.com/dp/B01C5A2WJO
# 24: https://www.amazon.com/dp/B007EA4UBY
# 25: https://www.amazon.com/dp/B00DW1JT5G
# 26: https://www.amazon.com/dp/B014Q1XX9S
# 27: https://www.amazon.com/dp/B01L0MJX0E
# 28: https://www.amazon.com/dp/B00FZMDAO6
# 29: https://www.amazon.com/dp/B00000IZJB
# 30: https://www.amazon.com/dp/B011PLVBJG
# 31: https://www.amazon.com/dp/B00G70DFC2
# 32: https://www.amazon.com/dp/1933054395
# 33: https://www.amazon.com/dp/B00008BFZH
# 34: https://www.amazon.com/dp/B00JM5GW10
# 35: https://www.amazon.com/dp/B077Z1R28P
# 36: https://www.amazon.com/dp/B07B6NP36Q
# 37: https://www.amazon.com/dp/B00SAUAP5C
# 38: https://www.amazon.com/dp/B07H2CKCNG
# 39: https://www.amazon.com/dp/B07FYF5DCK
# 40: https://www.amazon.com/dp/B00PYLU3GG
# 41: https://www.amazon.com/dp/B001I912SQ
# 42: https://www.amazon.com/dp/B086VB89L8
# 43: https://www.amazon.com/dp/B008CDR7LW
# 44: https://www.amazon.com/dp/B00U26V4VQ
# 45: https://www.amazon.com/dp/B078WKT1HL
# 46: https://www.amazon.com/dp/B0160JB7IS
# 47: https://www.amazon.com/dp/B07MNMT3M7
# 48: https://www.amazon.com/dp/B004UU9ZB6
# 49: https://www.amazon.com/dp/B000PEOMC8
# 50: https://www.amazon.com/dp/B00F4WMAI4
# 51: https://www.amazon.com/dp/B00592BOAO
# 52: https://www.amazon.com/dp/B00000K3BR
# 53: https://www.amazon.com/dp/B000FK3WDC
# 54: https://www.amazon.com/dp/B01256V578
# 55: https://www.amazon.com/dp/B076PRWVFG
# 56: https://www.amazon.com/dp/B00GGY85EC
# 57: https://www.amazon.com/dp/1932188126
# 58: https://www.amazon.com/dp/B01LQCIL88
# 59: https://www.amazon.com/dp/B00YTWEMUO
# 60: https://www.amazon.com/dp/B000KHZ044
# 61: https://www.amazon.com/dp/B00NHQFA1I
# 62: https://www.amazon.com/dp/B01DAPMQO4
# 63: https://www.amazon.com/dp/B000OV0X4S
# 64: https://www.amazon.com/dp/B01CIWDDMO
# 65: https://www.amazon.com/dp/B012D3PN7G
# 66: https://www.amazon.com/dp/0976990709
# 67: https://www.amazon.com/dp/B09DY34ZX3
# 68: https://www.amazon.com/dp/B00004TZY8
# 69: https://www.amazon.com/dp/B074PYYM51
# 70: https://www.amazon.com/dp/B0077Q0NP2
# 71: https://www.amazon.com/dp/B00A2HD40E
# 72: https://www.amazon.com/dp/B000EULZDM
# 73: https://www.amazon.com/dp/B002J4U8M0
# 74: https://www.amazon.com/dp/B0042F99PG
# 75: https://www.amazon.com/dp/B001SN8GF4
# 76: https://www.amazon.com/dp/B01HPM8MMI
# 77: https://www.amazon.com/dp/B07WH2YV47
# 78: https://www.amazon.com/dp/B00GQ4PBR6
# 79: https://www.amazon.com/dp/B018HB2QFU
# 80: https://www.amazon.com/dp/B004AHMCMI
# 81: https://www.amazon.com/dp/B07LG9CGF1
# 82: https://www.amazon.com/dp/B00000IZKX
# 83: https://www.amazon.com/dp/B00000ISC5
# 84: https://www.amazon.com/dp/B00CS16EJU
# 85: https://www.amazon.com/dp/B00006IFH0
# 86: https://www.amazon.com/dp/B071X8S8WQ
# 87: https://www.amazon.com/dp/B005K0B8WO
# 88: https://www.amazon.com/dp/B00OTJ5HZQ
# 89: https://www.amazon.com/dp/B082KFTF41
# 90: https://www.amazon.com/dp/B000VO3GPG
# 91: https://www.amazon.com/dp/B003NSBMUI
# 92: https://www.amazon.com/dp/B004A8ZRB0
# 93: https://www.amazon.com/dp/B00000J0S3
# 94: https://www.amazon.com/dp/B000068CKY
# 95: https://www.amazon.com/dp/B0006B2Q50
# 96: https://www.amazon.com/dp/B001BKX0V4
# 97: https://www.amazon.com/dp/B015OU8W3M
# 98: https://www.amazon.com/dp/B07L8RZC3C
# 99: https://www.amazon.com/dp/B004NCEL4M
# 100: https://www.amazon.com/dp/B01N037GIU
# 101: https://www.amazon.com/dp/B004HKQI9G
# 102: https://www.amazon.com/dp/B005HIOVOG
# 103: https://www.amazon.com/dp/B07G3ZNK4Y
# 104: https://www.amazon.com/dp/B007GE75G0
# 105: https://www.amazon.com/dp/B00068Q7LC
# 106: https://www.amazon.com/dp/B00JLHVX36
# 107: https://www.amazon.com/dp/B085ZH5VGR
# 108: https://www.amazon.com/dp/B00IZEUFIA
# 109: https://www.amazon.com/dp/B07VCD1SRL
# 110: https://www.amazon.com/dp/B010F029Y4
# 111: https://www.amazon.com/dp/B000F9O85E
# 112: https://www.amazon.com/dp/B07DLRMG95
# 113: https://www.amazon.com/dp/B01MQ3YP7Y
# 114: https://www.amazon.com/dp/B07DLR7C6H
# 115: https://www.amazon.com/dp/B0000BX8MA
# 116: https://www.amazon.com/dp/B003HC9734
# 117: https://www.amazon.com/dp/B00BN6QAVI
# 118: https://www.amazon.com/dp/B07V3CLLCV
# 119: https://www.amazon.com/dp/B00NCJ5CB8
# 120: https://www.amazon.com/dp/B00D7OAOYI
# 121: https://www.amazon.com/dp/B003D7F4YY
# 122: https://www.amazon.com/dp/B001NQHN7S
# 123: https://www.amazon.com/dp/B00N1EJXUU
# 124: https://www.amazon.com/dp/B0006O8Q7Y
# 125: https://www.amazon.com/dp/B07TQLRGJR
# 126: https://www.amazon.com/dp/B083KBNJ63
# 127: https://www.amazon.com/dp/B07P5X2F4X
# 128: https://www.amazon.com/dp/B00CIXVITO
# 129: https://www.amazon.com/dp/B002JCS5JA
# 130: https://www.amazon.com/dp/B07F38CPM1
# 131: https://www.amazon.com/dp/B08DNYW674
# 132: https://www.amazon.com/dp/B007XVYSDE
# 133: https://www.amazon.com/dp/B01H1NV1RE
# 134: https://www.amazon.com/dp/B07PBXRJ7G
# 135: https://www.amazon.com/dp/B01D7SS1X4
# 136: https://www.amazon.com/dp/B009VE38CI
# 137: https://www.amazon.com/dp/B078WM314M
# 138: https://www.amazon.com/dp/B00CI6J5JQ
# 139: https://www.amazon.com/dp/B000CBSNRY
# 140: https://www.amazon.com/dp/B00N7CD4BK
# 141: https://www.amazon.com/dp/B001UF8BL4
# 142: https://www.amazon.com/dp/B016XIMFQY
# 143: https://www.amazon.com/dp/B00R0V7PUU
# 144: https://www.amazon.com/dp/B07MLYQLX1
# 145: https://www.amazon.com/dp/B000BN8Y8G
# 146: https://www.amazon.com/dp/B000PKFJKG
# 147: https://www.amazon.com/dp/B000BURAP2
# 148: https://www.amazon.com/dp/B00CI6J3HA
# 149: https://www.amazon.com/dp/B008J1QP7Y
# 150: https://www.amazon.com/dp/B000N178E2
# 151: https://www.amazon.com/dp/B01N5C39CX
# 152: https://www.amazon.com/dp/B07477HKFR
# 153: https://www.amazon.com/dp/B000067R86
# 154: https://www.amazon.com/dp/B000WD3XBI
# 155: https://www.amazon.com/dp/B00F4WMAAW
# 156: https://www.amazon.com/dp/B074ZHXF48
# 157: https://www.amazon.com/dp/B072L6MNX1
# 158: https://www.amazon.com/dp/B07DLQMN8G
# 159: https://www.amazon.com/dp/B00BB7YETE
# 160: https://www.amazon.com/dp/B00GHAGGOG
# 161: https://www.amazon.com/dp/B009JBJ142
# 162: https://www.amazon.com/dp/B000197NXM
# 163: https://www.amazon.com/dp/B079CH7PLF
# 164: https://www.amazon.com/dp/B002PEGT9U
# 165: https://www.amazon.com/dp/B06XZNMMKC
# 166: https://www.amazon.com/dp/B009R6J8RY
# 167: https://www.amazon.com/dp/B000I2Q0F4
# 168: https://www.amazon.com/dp/B00IUAAK2A
# 169: https://www.amazon.com/dp/B07SHQ9Y7B
# 170: https://www.amazon.com/dp/B07H331J4R
# 171: https://www.amazon.com/dp/B01E2X47SG
# 172: https://www.amazon.com/dp/B000NZQ010
# 173: https://www.amazon.com/dp/B002V7A7MQ
# 174: https://www.amazon.com/dp/B07C2YPYBM
# 175: https://www.amazon.com/dp/B00005TQI7
# 176: https://www.amazon.com/dp/B01K1K0K6M
# 177: https://www.amazon.com/dp/B06XKXPLRP
# 178: https://www.amazon.com/dp/B083BCTLP5
# 179: https://www.amazon.com/dp/B006EFMSSM
# 180: https://www.amazon.com/dp/B0107H5FJ6
# 181: https://www.amazon.com/dp/B00J57VU44
# 182: https://www.amazon.com/dp/B00HT5HBMO
# 183: https://www.amazon.com/dp/B07Q9Z5TVX
# 184: https://www.amazon.com/dp/B002IMMDN0
# 185: https://www.amazon.com/dp/B01C35QC4W
# 186: https://www.amazon.com/dp/B085HNMHKJ
# 187: https://www.amazon.com/dp/B01N6B8SX0
# 188: https://www.amazon.com/dp/B071FLSWBS
# 189: https://www.amazon.com/dp/B00001ZWV7
# 190: https://www.amazon.com/dp/B000058TJ3
# 191: https://www.amazon.com/dp/B00C6Q1Z6E
# 192: https://www.amazon.com/dp/B016BMBRUM
# 193: https://www.amazon.com/dp/B00PM722OI
# 194: https://www.amazon.com/dp/B004LO2AIG
# 195: https://www.amazon.com/dp/B07MYTBV6N
# 196: https://www.amazon.com/dp/B07XV8C1G5
# 197: https://www.amazon.com/dp/B010TU7LP2
# 198: https://www.amazon.com/dp/B00I3K25R0
# 199: https://www.amazon.com/dp/B003ADVR3S
# 200: https://www.amazon.com/dp/B06XZ9K244
# 201: https://www.amazon.com/dp/B085NDX8Y2
# 202: https://www.amazon.com/dp/B00JM5GZGW
# 203: https://www.amazon.com/dp/B00CPHX6YI
# 204: https://www.amazon.com/dp/B00005RF5G
# 205: https://www.amazon.com/dp/B00ZY6JHU4
# 206: https://www.amazon.com/dp/B000L8EEPS
# 207: https://www.amazon.com/dp/B003AIM52A
# 208: https://www.amazon.com/dp/B008CO80SA
# 209: https://www.amazon.com/dp/B004A8ZRBA
# 210: https://www.amazon.com/dp/B00486ZVC4
# 211: https://www.amazon.com/dp/B01N074ELB
# 212: https://www.amazon.com/dp/B074YYVXQH
# 213: https://www.amazon.com/dp/B00YBWOMRA
# 214: https://www.amazon.com/dp/B073PTTDX5
# 215: https://www.amazon.com/dp/B0054KBV4U
# 216: https://www.amazon.com/dp/B00AA7BA3Y
# 217: https://www.amazon.com/dp/B00005KBVD
# 218: https://www.amazon.com/dp/B011JV9HA2
# 219: https://www.amazon.com/dp/B004A2QTRC
# 220: https://www.amazon.com/dp/B071YCHDX1
# 221: https://www.amazon.com/dp/B000EDQGLK
# 222: https://www.amazon.com/dp/0786965622
# 223: https://www.amazon.com/dp/B07C5F2TNG
# 224: https://www.amazon.com/dp/B07NXDJ52C
# 225: https://www.amazon.com/dp/B00TTU9RAQ
# 226: https://www.amazon.com/dp/B087R4RD1Z
# 227: https://www.amazon.com/dp/B004YD7BTW
# 228: https://www.amazon.com/dp/B005FYEAJ8
# 229: https://www.amazon.com/dp/B01KJEOCDW
# 230: https://www.amazon.com/dp/B01F9MO9PU
# 231: https://www.amazon.com/dp/B00005O6B7
# 232: https://www.amazon.com/dp/B00NGZ70ZO
# 233: https://www.amazon.com/dp/B01IK37D3A
# 234: https://www.amazon.com/dp/B000YFSZU8
# 235: https://www.amazon.com/dp/B007XVYPS2
# 236: https://www.amazon.com/dp/B00008W72D
# 237: https://www.amazon.com/dp/B0160JBGRA
# 238: https://www.amazon.com/dp/B07BHQ81XG
# 239: https://www.amazon.com/dp/B00D8VHIMG
# 240: https://www.amazon.com/dp/B07DB2NQ3N
# 241: https://www.amazon.com/dp/B01NBGIXG5
# 242: https://www.amazon.com/dp/B004N7NFSK
# 243: https://www.amazon.com/dp/B01MUC9GPU
# 244: https://www.amazon.com/dp/B01C49MCCS
# 245: https://www.amazon.com/dp/B00C2P6VWW
# 246: https://www.amazon.com/dp/B07CCFDZZ3
# 247: https://www.amazon.com/dp/B01CQTWBYK
# 248: https://www.amazon.com/dp/B0000205XI
# 249: https://www.amazon.com/dp/B079997BXY

# %%
expensive_asins = ['B01C49MCCS',
                  'B004A2QTRC',
                  'B00005KBVD',
                  'B074YYVXQH',
                  'B085HNMHKJ',
                  'B0107H5FJ6',
                  'B002PEGT9U',
                  'B000CBSNRY',
                  'B07F38CPM1',
                  'B07V3CLLCV',
                  'B07VCD1SRL',
                  'B07G3ZNK4Y',
                  'B003NSBMUI',
                  'B0042F99PG',
                  'B00592BOAO']

# %%
for chunk in pd.read_json(file, lines=True, chunksize=50000):
    df = chunk
    break

# %%
import os, json
from collections import Counter, defaultdict
import pandas as pd

path = file   # <-- your JSONL path

def stream_json_objects(path):
    """Yield dict objects from a JSONL file; skip blanks, 'false', arrays, malformed, etc."""
    with open(path, "r", encoding="utf-8") as f:
        for i, line in enumerate(f, 1):
            s = line.strip()
            if not s:
                continue
            try:
                obj = json.loads(s)
            except Exception:
                # malformed line; skip
                continue
            if isinstance(obj, dict):
                yield obj  # only objects are valid rows

# 1) First pass: find top 25 ASINs (robust to bad lines)
asin_counts = Counter()
for obj in stream_json_objects(path):
    a = obj.get("asin")
    if a:
        asin_counts[a] += 1

retro_top_25 = [a for a, _ in asin_counts.most_common(25)]
top25 = expensive_asins + retro_top_25#[a for a, _ in asin_counts.most_common(25)]
top25_set = set(top25)#set(top25)

print("Top 25 ASINs:", top25)

# 2) Second pass: write rows for those ASINs to per-ASIN files incrementally (memory-safe)
buffers = defaultdict(list)
flush_every = 10000  # adjust as you like

def flush(asin):
    """Append buffer to CSV for this ASIN, then clear buffer."""
    out = f"asin_{asin}.csv"
    df = pd.DataFrame.from_records(buffers[asin])
    df.to_csv(out, mode="a", index=False, header=not os.path.exists(out))
    buffers[asin].clear()

# remove old outputs if you’re re-running (optional)
for a in top25:
    out = f"asin_{a}.csv"
    if os.path.exists(out):
        os.remove(out)

for obj in stream_json_objects(path):
    a = obj.get("asin")
    if a in top25_set:
        buffers[a].append(obj)
        if len(buffers[a]) >= flush_every:
            flush(a)

# final flush
for a in list(buffers.keys()):
    if buffers[a]:
        flush(a)

# 3) If you want in-memory DataFrames now (optional; uses RAM):
dfs = {a: pd.read_csv(f"asin_{a}.csv") for a in top25 if os.path.exists(f"asin_{a}.csv")}
# Out:
# Top 25 ASINs: ['B01C49MCCS', 'B004A2QTRC', 'B00005KBVD', 'B074YYVXQH', 'B085HNMHKJ', 'B0107H5FJ6', 'B002PEGT9U', 'B000CBSNRY', 'B07F38CPM1', 'B07V3CLLCV', 'B07VCD1SRL', 'B07G3ZNK4Y', 'B003NSBMUI', 'B0042F99PG', 'B00592BOAO', 'B004S8F7QM', 'B000YDDF6O', 'B010TQY7A8', 'B00005C5H4', 'B004V3PS72', 'B01MRG7T0D', 'B01AC7SF7K', 'B00ABA0ZOA', 'B000B6ACGA', 'B0157IHJMQ', 'B0120XRWLE', 'B00AU56C5W', 'B001CJVTLC', 'B00000IV35', 'B00A80X19E', '0975277324', 'B00000IVAK', 'B003I64OT6', 'B00D8STBHY', 'B00APVXSM6', 'B00MNG37C2', '8499000606', 'B00NQQTZCO', 'B01C5A2WJO', 'B007EA4UBY']

# %%
dfs.keys()
# Out:
# dict_keys(['B01C49MCCS', 'B004A2QTRC', 'B00005KBVD', 'B074YYVXQH', 'B085HNMHKJ', 'B0107H5FJ6', 'B002PEGT9U', 'B000CBSNRY', 'B07F38CPM1', 'B07V3CLLCV', 'B07VCD1SRL', 'B07G3ZNK4Y', 'B003NSBMUI', 'B0042F99PG', 'B00592BOAO', 'B004S8F7QM', 'B000YDDF6O', 'B010TQY7A8', 'B00005C5H4', 'B004V3PS72', 'B01MRG7T0D', 'B01AC7SF7K', 'B00ABA0ZOA', 'B000B6ACGA', 'B0157IHJMQ', 'B0120XRWLE', 'B00AU56C5W', 'B001CJVTLC', 'B00000IV35', 'B00A80X19E', '0975277324', 'B00000IVAK', 'B003I64OT6', 'B00D8STBHY', 'B00APVXSM6', 'B00MNG37C2', '8499000606', 'B00NQQTZCO', 'B01C5A2WJO', 'B007EA4UBY'])

# %%
# df = dfs['B004S8F7QM']
# df.to_csv("CardsAgainstHumanityAmazonReviewData.csv")

# %%
blocked_asins = ['B0157IHJMQ', '8499000606']

# %%
top25 = [x for x in top25 if x not in blocked_asins]

# %%
top_asins = top25#['B004S8F7QM', 'B000YDDF6O', 'B010TQY7A8', 'B00005C5H4', 'B004V3PS72', 'B01MRG7T0D', 'B01AC7SF7K', 'B00ABA0ZOA', 'B000B6ACGA', 'B0120XRWLE', 'B00AU56C5W', 'B001CJVTLC', 'B00000IV35', 'B00A80X19E', '0975277324', 'B00000IVAK', 'B003I64OT6', 'B00D8STBHY', 'B00APVXSM6', 'B00MNG37C2', 'B00NQQTZCO', 'B01C5A2WJO', 'B007EA4UBY']

# %%
# top_asins = expensive_asins

# %%
for asin in top_asins:
    print(f"https://www.amazon.com/dp/{asin}")
# Out:
# https://www.amazon.com/dp/B01C49MCCS
# https://www.amazon.com/dp/B004A2QTRC
# https://www.amazon.com/dp/B00005KBVD
# https://www.amazon.com/dp/B074YYVXQH
# https://www.amazon.com/dp/B085HNMHKJ
# https://www.amazon.com/dp/B0107H5FJ6
# https://www.amazon.com/dp/B002PEGT9U
# https://www.amazon.com/dp/B000CBSNRY
# https://www.amazon.com/dp/B07F38CPM1
# https://www.amazon.com/dp/B07V3CLLCV
# https://www.amazon.com/dp/B07VCD1SRL
# https://www.amazon.com/dp/B07G3ZNK4Y
# https://www.amazon.com/dp/B003NSBMUI
# https://www.amazon.com/dp/B0042F99PG
# https://www.amazon.com/dp/B00592BOAO
# https://www.amazon.com/dp/B004S8F7QM
# https://www.amazon.com/dp/B000YDDF6O
# https://www.amazon.com/dp/B010TQY7A8
# https://www.amazon.com/dp/B00005C5H4
# https://www.amazon.com/dp/B004V3PS72
# https://www.amazon.com/dp/B01MRG7T0D
# https://www.amazon.com/dp/B01AC7SF7K
# https://www.amazon.com/dp/B00ABA0ZOA
# https://www.amazon.com/dp/B000B6ACGA
# https://www.amazon.com/dp/B0120XRWLE
# https://www.amazon.com/dp/B00AU56C5W
# https://www.amazon.com/dp/B001CJVTLC
# https://www.amazon.com/dp/B00000IV35
# https://www.amazon.com/dp/B00A80X19E
# https://www.amazon.com/dp/0975277324
# https://www.amazon.com/dp/B00000IVAK
# https://www.amazon.com/dp/B003I64OT6
# https://www.amazon.com/dp/B00D8STBHY
# https://www.amazon.com/dp/B00APVXSM6
# https://www.amazon.com/dp/B00MNG37C2
# https://www.amazon.com/dp/B00NQQTZCO
# https://www.amazon.com/dp/B01C5A2WJO
# https://www.amazon.com/dp/B007EA4UBY

# %%
products = [
    "Ultimate kitchen playset",
    "Play kitchen",
    "Kid roller coaster",
    "HD drone",
    "4k drone",
    "BB-8 Toy",
    "Mini John Deere",
    "Magna Tiles",
    "Remote control monster truck",
    "GPS drone",
    "Camera drone",
    "Vector robot",
    "Mini bounce house",
    "Jumbo doll house",
    "Mini play kitchen",
    "Cards Against Humanity",
    "Baby Einstein Toy",
    "Exploding Kittens",
    "baby stacking cups",
    "dyson vacuum toy",
    "what do you meme",
    "stuffed elephant",
    "jenga",
    "automatic card shuffler",
    "princess castle tent",
    "magnet tiles",
    "pokemon cards",
    "five crowns",
    "gumby toy",
    "ticket to ride",
    "sequence game",
    "left right center",
    "connect 4",
    "magnet tiles",
    "drone toy",
    "monopoly deal",
    "little tikes basketball",
    "suspend game"
]

# %%
len(products)
# Out:
# 38

# %%
len(top25)
# Out:
# 38

# %%
top25
# Out:
# ['B01C49MCCS',
#  'B004A2QTRC',
#  'B00005KBVD',
#  'B074YYVXQH',
#  'B085HNMHKJ',
#  'B0107H5FJ6',
#  'B002PEGT9U',
#  'B000CBSNRY',
#  'B07F38CPM1',
#  'B07V3CLLCV',
#  'B07VCD1SRL',
#  'B07G3ZNK4Y',
#  'B003NSBMUI',
#  'B0042F99PG',
#  'B00592BOAO',
#  'B004S8F7QM',
#  'B000YDDF6O',
#  'B010TQY7A8',
#  'B00005C5H4',
#  'B004V3PS72',
#  'B01MRG7T0D',
#  'B01AC7SF7K',
#  'B00ABA0ZOA',
#  'B000B6ACGA',
#  'B0120XRWLE',
#  'B00AU56C5W',
#  'B001CJVTLC',
#  'B00000IV35',
#  'B00A80X19E',
#  '0975277324',
#  'B00000IVAK',
#  'B003I64OT6',
#  'B00D8STBHY',
#  'B00APVXSM6',
#  'B00MNG37C2',
#  'B00NQQTZCO',
#  'B01C5A2WJO',
#  'B007EA4UBY']

# %%
for i in range(len(top25)):
    print(products[i])
    print(f"https://www.amazon.com/dp/{top25[i]}")
    print()
# Out:
# Ultimate kitchen playset
# https://www.amazon.com/dp/B01C49MCCS
#
# Play kitchen
# https://www.amazon.com/dp/B004A2QTRC
#
# Kid roller coaster
# https://www.amazon.com/dp/B00005KBVD
#
# HD drone
# https://www.amazon.com/dp/B074YYVXQH
#
# 4k drone
# https://www.amazon.com/dp/B085HNMHKJ
#
# BB-8 Toy
# https://www.amazon.com/dp/B0107H5FJ6
#
# Mini John Deere
# https://www.amazon.com/dp/B002PEGT9U
#
# Magna Tiles
# https://www.amazon.com/dp/B000CBSNRY
#
# Remote control monster truck
# https://www.amazon.com/dp/B07F38CPM1
#
# GPS drone
# https://www.amazon.com/dp/B07V3CLLCV
#
# Camera drone
# https://www.amazon.com/dp/B07VCD1SRL
#
# Vector robot
# https://www.amazon.com/dp/B07G3ZNK4Y
#
# Mini bounce house
# https://www.amazon.com/dp/B003NSBMUI
#
# Jumbo doll house
# https://www.amazon.com/dp/B0042F99PG
#
# Mini play kitchen
# https://www.amazon.com/dp/B00592BOAO
#
# Cards Against Humanity
# https://www.amazon.com/dp/B004S8F7QM
#
# Baby Einstein Toy
# https://www.amazon.com/dp/B000YDDF6O
#
# Exploding Kittens
# https://www.amazon.com/dp/B010TQY7A8
#
# baby stacking cups
# https://www.amazon.com/dp/B00005C5H4
#
# dyson vacuum toy
# https://www.amazon.com/dp/B004V3PS72
#
# what do you meme
# https://www.amazon.com/dp/B01MRG7T0D
#
# stuffed elephant
# https://www.amazon.com/dp/B01AC7SF7K
#
# jenga
# https://www.amazon.com/dp/B00ABA0ZOA
#
# automatic card shuffler
# https://www.amazon.com/dp/B000B6ACGA
#
# princess castle tent
# https://www.amazon.com/dp/B0120XRWLE
#
# magnet tiles
# https://www.amazon.com/dp/B00AU56C5W
#
# pokemon cards
# https://www.amazon.com/dp/B001CJVTLC
#
# five crowns
# https://www.amazon.com/dp/B00000IV35
#
# gumby toy
# https://www.amazon.com/dp/B00A80X19E
#
# ticket to ride
# https://www.amazon.com/dp/0975277324
#
# sequence game
# https://www.amazon.com/dp/B00000IVAK
#
# left right center
# https://www.amazon.com/dp/B003I64OT6
#
# connect 4
# https://www.amazon.com/dp/B00D8STBHY
#
# magnet tiles
# https://www.amazon.com/dp/B00APVXSM6
#
# drone toy
# https://www.amazon.com/dp/B00MNG37C2
#
# monopoly deal
# https://www.amazon.com/dp/B00NQQTZCO
#
# little tikes basketball
# https://www.amazon.com/dp/B01C5A2WJO
#
# suspend game
# https://www.amazon.com/dp/B007EA4UBY

# %%
# products = [
#     "Cards Against Humanity",
#     "Baby Einstein Toy",
#     "Exploding Kittens",
#     "baby stacking cups",
#     "dyson vacuum toy",
#     "what do you meme",
#     "stuffed elephant",
#     "jenga",
#     "automatic card shuffler",
#     "princess castle tent",
#     "magnet tiles",
#     "pokemon cards",
#     "five crowns",
#     "gumby toy",
#     "ticket to ride",
#     "sequence game",
#     "left right center",
#     "connect 4",
#     "magnet tiles",
#     "drone toy",
#     "monopoly deal",
#     "little tikes basketball",
#     "suspend game"
# ]

# %%
asin_to_prod = {}
for i in range(len(top_asins)):
    asin_to_prod[top_asins[i]] = products[i]

# %%
a2p = pd.DataFrame.from_dict(asin_to_prod, orient='index', columns=['product_name']).reset_index()
a2p = a2p.rename(columns={'index': 'asin'})

# Add is_expensive column
a2p['is_expensive'] = a2p['asin'].isin(expensive_asins)

a2p.to_csv("asin_to_product_name_and_is_expensive.csv", index=False)

# %%
for asin in top_asins:
    df = dfs[asin]
    name = asin_to_prod[asin]
    df.to_csv(name.replace(' ', '_') + '.csv')

# %%
dfs.keys()
# Out:
# dict_keys(['B01C49MCCS', 'B004A2QTRC', 'B00005KBVD', 'B074YYVXQH', 'B085HNMHKJ', 'B0107H5FJ6', 'B002PEGT9U', 'B000CBSNRY', 'B07F38CPM1', 'B07V3CLLCV', 'B07VCD1SRL', 'B07G3ZNK4Y', 'B003NSBMUI', 'B0042F99PG', 'B00592BOAO', 'B004S8F7QM', 'B000YDDF6O', 'B010TQY7A8', 'B00005C5H4', 'B004V3PS72', 'B01MRG7T0D', 'B01AC7SF7K', 'B00ABA0ZOA', 'B000B6ACGA', 'B0157IHJMQ', 'B0120XRWLE', 'B00AU56C5W', 'B001CJVTLC', 'B00000IV35', 'B00A80X19E', '0975277324', 'B00000IVAK', 'B003I64OT6', 'B00D8STBHY', 'B00APVXSM6', 'B00MNG37C2', '8499000606', 'B00NQQTZCO', 'B01C5A2WJO', 'B007EA4UBY'])

# %%
dummy_df = pd.concat(
    [
        df.sample(n=25, replace=False, random_state=None)
        if len(df) >= 25
        else df.sample(n=25, replace=True, random_state=None)
        for df in dfs.values()
    ],
    ignore_index=True
)

# %%
dummy_df.columns
# Out:
# Index(['rating', 'title', 'text', 'images', 'asin', 'parent_asin', 'user_id',
#        'timestamp', 'helpful_vote', 'verified_purchase'],
#       dtype='object')

# %%
for asin, name in asin_to_prod.items():
    print(f"""{asin}:{name}""")
# Out:
# B01C49MCCS:Ultimate kitchen playset
# B004A2QTRC:Play kitchen
# B00005KBVD:Kid roller coaster
# B074YYVXQH:HD drone
# B085HNMHKJ:4k drone
# B0107H5FJ6:BB-8 Toy
# B002PEGT9U:Mini John Deere
# B000CBSNRY:Magna Tiles
# B07F38CPM1:Remote control monster truck
# B07V3CLLCV:GPS drone
# B07VCD1SRL:Camera drone
# B07G3ZNK4Y:Vector robot
# B003NSBMUI:Mini bounce house
# B0042F99PG:Jumbo doll house
# B00592BOAO:Mini play kitchen
# B004S8F7QM:Cards Against Humanity
# B000YDDF6O:Baby Einstein Toy
# B010TQY7A8:Exploding Kittens
# B00005C5H4:baby stacking cups
# B004V3PS72:dyson vacuum toy
# B01MRG7T0D:what do you meme
# B01AC7SF7K:stuffed elephant
# B00ABA0ZOA:jenga
# B000B6ACGA:automatic card shuffler
# B0120XRWLE:princess castle tent
# B00AU56C5W:magnet tiles
# B001CJVTLC:pokemon cards
# B00000IV35:five crowns
# B00A80X19E:gumby toy
# 0975277324:ticket to ride
# B00000IVAK:sequence game
# B003I64OT6:left right center
# B00D8STBHY:connect 4
# B00APVXSM6:magnet tiles
# B00MNG37C2:drone toy
# B00NQQTZCO:monopoly deal
# B01C5A2WJO:little tikes basketball
# B007EA4UBY:suspend game

# %%
dummy_df
# Out:
#      rating                                              title  \
# 0       4.0  The directions were not the best. But it's so ...
# 1       5.0                             You’ll have to read…..
# 2       4.0                      Nice design but pointy edges!
# 3       4.0                                         Super cute
# 4       5.0                     They play with it all the time
# ..      ...                                                ...
# 370     5.0                          Best little kitchen ever!
# 371     5.0                       Amazing children's kitchen!!
# 372     5.0                                         Five Stars
# 373     1.0                                        Frustration
# 374     5.0  Great quality play kitchen! Takes awhile to as...
#
#                                                   text  \
# 0    It took 3 hours to put together. The direction...
# 1    Ok first off. Great little set. That said. It ...
# 2    Fun design but not the safest for a toddler. V...
# 3    Super cute and my kids love it. I know it was ...
# 4                                     The kids love it
# ..                                                 ...
# 370  After a year, still in great shape and used ev...
# 371  We bought this kitchen for my 18 month old son...
# 372             Awesome product at an awesome price!!!
# 373  After one horrible incident with a replacement...
# 374  This play kitchen was my  2yr old daughters ma...
#
#                                                 images        asin  \
# 0                                                   []  B01C49MCCS
# 1                                                   []  B01C49MCCS
# 2    [{'small_image_url': 'https://m.media-amazon.c...  B01C49MCCS
# 3                                                   []  B01C49MCCS
# 4                                                   []  B01C49MCCS
# ..                                                 ...         ...
# 370                                                 []  B00592BOAO
# 371                                                 []  B00592BOAO
# 372                                                 []  B00592BOAO
# 373                                                 []  B00592BOAO
# 374                                                 []  B00592BOAO
#
#     parent_asin                       user_id      timestamp  helpful_vote  \
# 0    B01LALE67U  AHYPQYEGDQ4PBE3J7XX2E5HRZ4EA  1522142471477             0
# 1    B01LALE67U  AHXNLMWRFXQKHJUSAH6SRAFZKVAA  1641252798573             0
# 2    B01LALE67U  AEQKS6DGPEFKN3HPKCS365IZY3SA  1672057601201             0
# 3    B01LALE67U  AFTO77SDFFZS5BCKOEUCS2DVWENA  1580649384265             0
# 4    B01LALE67U  AE7GZBYNJ6Z2ZWR6DSP2AAN2QJHA  1577454625188             0
# ..          ...                           ...            ...           ...
# 370  B00ELRFLZM  AFA3W5SUTFLU4C32NNKFRUJR45UA  1481837754000             1
# 371  B00ELRFLZM  AGVMVQGYGCC62JNUKPEY23Z4PEPQ  1355290132000             1
# 372  B00ELRFLZM  AF7OLVQ25SFSEK5YSIOIVBUFSL2A  1419540946000             0
# 373  B00ELRFLZM  AFJ7RSEK6GLTCIIHB3LV7FNIAYCA  1463182323000             2
# 374  B00ELRFLZM  AF2NNNZXEM7ID4H6CJIPYMBXO5WA  1551059002872             0
#
#      verified_purchase
# 0                 True
# 1                 True
# 2                 True
# 3                 True
# 4                 True
# ..                 ...
# 370               True
# 371               True
# 372               True
# 373               True
# 374               True
#
# [375 rows x 10 columns]

# %%
# df = dfs['B01MRG7T0D'].copy()
# df = df[df['rating'] == 1]

# for t in df['text']:
#     print(t)
#     print()

# %%
prod_names = [asin_to_prod[key] for key in asin_to_prod]
csv_names = [name.replace(' ', '_') + '.csv' for name in prod_names]
dfs = [pd.read_csv(name) for name in csv_names]
combined_df = pd.concat(dfs, axis=0, ignore_index=True)
combined_df = combined_df.drop(columns=['Unnamed: 0'])
print(f"Combined shape: {combined_df.shape}")
# Out:
# Combined shape: (177960, 10)

# %%
combined_df.head()
# Out:
#    rating                                          title  \
# 0     5.0                      A lot of fun for Toddlers
# 1     5.0  Very nice product for all those future chefs!
# 2     1.0                    Came missing a ton of parts
# 3     4.0                         Good toy for grandkids
# 4     5.0                                     Five Stars
#
#                                                 text  \
# 0  It’s awesome and my grandson (2) loves it.  He...
# 1  Very nice product! Item was packed very well a...
# 2  Wanted to love this, so many parts and screws....
# 3  Got this for my two grandchildren for Christma...
# 4                                              Great
#
#                                               images        asin parent_asin  \
# 0                                                 []  B01C49MCCS  B01LALE67U
# 1  [{'small_image_url': 'https://images-na.ssl-im...  B01C49MCCS  B01LALE67U
# 2                                                 []  B01C49MCCS  B01LALE67U
# 3                                                 []  B01C49MCCS  B01LALE67U
# 4                                                 []  B01C49MCCS  B01LALE67U
#
#                         user_id      timestamp  helpful_vote  \
# 0  AFTEZMTDJTMY4YIU4HJQEQY35BXQ  1609892936645             0
# 1  AHRU3HJGLE5IC4VQFCGT5P4CGOLA  1521960365136             2
# 2  AGRXOSYV2XJIBYVOHKL4TTXSRHLQ  1657390116692             2
# 3  AGCGSPZP6XTN5LTOFCAZK2E6MVFQ  1550940421664             0
# 4  AEXGVJXXCE4R4Y377KYNB4K2GFQA  1501690697903             0
#
#    verified_purchase
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True

# %%
combined_df.to_csv("combined_csv.csv")
